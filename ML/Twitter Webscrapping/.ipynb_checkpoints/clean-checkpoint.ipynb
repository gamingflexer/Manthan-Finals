# %%
import pandas as pd
import re
import twint

# %%
# USING WEB SCRAPPING 

#scrap 

c = twint.Config()

#for k in ky:
c.Search = "ISIS"
c.Limit= 300
c.Min_likes = 3
c.Custom["tweet"] = ["id", "username","tweet"]
c.Output="10.json"
c.Store_json=True

c.Hide_output = True

twint.run.Search(c)

# %%
data = pd.read_csv (r'1.csv')
print (data)
# Out:
#                       id      conversation_id  \
# 0    1445227479321382916  1445227479321382916
# 1    1445227452788269057  1445100293805445122
# 2    1445226349514297346  1445226349514297346
# 3    1445225572813135873  1445225572813135873
# 4    1445225278913929220  1445224054898704385
# ..                   ...                  ...
# 295  1445174357144195074  1445174357144195074
# 296  1445174145780695043  1445174145780695043
# 297  1445173910710980609  1444691764028248069
# 298  1445173731505152002  1445173731505152002
# 299  1445173729907167233  1445173729907167233
#
#                                   created_at        date      time  timezone  \
# 0    2021-10-05 08:50:56 India Standard Time  2021-10-05  08:50:56       530
# 1    2021-10-05 08:50:50 India Standard Time  2021-10-05  08:50:50       530
# 2    2021-10-05 08:46:27 India Standard Time  2021-10-05  08:46:27       530
# 3    2021-10-05 08:43:22 India Standard Time  2021-10-05  08:43:22       530
# ...

# %%
data['tweet'] = data['tweet'].apply(lambda x: x.lower())
data['tweet'] = data['tweet'].apply(lambda x: " ".join (re.sub(r'([a-zA-Z0-9+._-]+@[a-zA-Z0-9+._-]+\.[a-zA-Z0-9_-]+)'," ",x).split()))
data['tweet'] = data['tweet'].apply(lambda x:" ".join (re.sub(r'(http|ftp|https)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', "", x).split()))
data['tweet'] = data['tweet'].apply(lambda x:" ".join (re.sub('[^A-Z a-z 0-9-]+', "", x).split()))
data['tweet'] =data['tweet'].apply(lambda x:" ".join (re.sub('rt', "",x).split()))

# %%
data
# Out:
#                       id      conversation_id  \
# 0    1445227479321382916  1445227479321382916
# 1    1445227452788269057  1445100293805445122
# 2    1445226349514297346  1445226349514297346
# 3    1445225572813135873  1445225572813135873
# 4    1445225278913929220  1445224054898704385
# ..                   ...                  ...
# 295  1445174357144195074  1445174357144195074
# 296  1445174145780695043  1445174145780695043
# 297  1445173910710980609  1444691764028248069
# 298  1445173731505152002  1445173731505152002
# 299  1445173729907167233  1445173729907167233
#
#                                   created_at        date      time  timezone  \
# 0    2021-10-05 08:50:56 India Standard Time  2021-10-05  08:50:56       530
# 1    2021-10-05 08:50:50 India Standard Time  2021-10-05  08:50:50       530
# 2    2021-10-05 08:46:27 India Standard Time  2021-10-05  08:46:27       530
# 3    2021-10-05 08:43:22 India Standard Time  2021-10-05  08:43:22       530
# ...

# %%
data['tweet']
# Out:
# 0      this is the tweet no more shelters no more nav...
# 1                          dianap m hubiera ido a dormir
# 2      in the evening two key members of the khawarij...
# 3                                                 a fact
# 4      mediaite and if shes still not going to answer...
#                              ...
# 295    pengasong radikal radikul melongo goblog karen...
# 296                                                 y si
# 297    txlinmelendez katibug817 realchattycat gabbyuc...
# 298    o caos foi instaurado to esperando o anticrist...
# 299    venir al crucero con mis amigxs siempre es bue...
# Name: tweet, Length: 300, dtype: object

# %%
data.to_csv(r'final.csv',index=True)
